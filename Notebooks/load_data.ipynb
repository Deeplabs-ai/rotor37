# %%
__author__ = "Marco Sanguineti"
__copyright__ = "Copyright (C) 2022 Deeplabs"
__license__ = "MIT"
__version__ = "1.0"

# %%
# %%bash
# python --version
# Out:
# Python 3.8.10

# %%
import numpy as np
import pandas as pd
import os
import plotly.graph_objects as go

# %%
if 'flag' not in vars():
    os.chdir(os.path.dirname(os.getcwd()))
    flag = 0

# %%
tabular_data_path = 'data/edp.csv'
geometries_path_1 = 'data/geometries_1.npy'
geometries_path_2 = 'data/geometries_2.npy'

# %%
tabular_data = pd.read_csv(tabular_data_path)
tabular_data.head()
# Out:
#    SEGMENT_2_RTHETA_STACKING_CURVE_POINT1  \
# 0                                0.000000
# 1                               -0.001104
# 2                               -0.000072
# 3                               -0.001436
# 4                               -0.001390
#
#    SEGMENT_2_RTHETA_STACKING_CURVE_POINT2  \
# 0                               -0.000644
# 1                               -0.000271
# 2                               -0.000910
# 3                               -0.001638
# 4                               -0.000064
#
#    SEGMENT_2_RTHETA_STACKING_CURVE_POINT3  SEGMENT_2_SECTION1_CHORD  \
# 0                               -0.001181                  0.056060
# 1                               -0.001202                  0.052381
# 2                               -0.000358                  0.054889
# 3                               -0.000787                  0.058244
# 4                               -0.000780                  0.058832
#
#    SEGMENT_2_SECTION1_EXITANGLE  SEGMENT_2_SECTION1_INLETANGLE  \
# 0                    -16.840000                     -54.600000
# 1                    -20.411404                     -56.048547
# 2                    -15.413896                     -50.466458
# 3                    -17.800147                     -56.330498
# 4                    -12.090686                     -50.456653
#
#    SEGMENT_2_SECTION1_LEWEDGEANGLE  SEGMENT_2_SECTION1_STAGGERANGLE  \
# 0                         8.000000                       -39.000000
# 1                         6.510772                       -39.946554
# 2                         0.065676                       -37.194421
# 3                         1.629584                       -39.956963
# 4                         6.620870                       -40.727102
#
#    SEGMENT_2_SECTION1_TEWEDGEANGLE  SEGMENT_2_SECTION1_THICKNESS_POINT3  ...  \
# 0                        12.000000                             0.003518  ...
# 1                        11.902398                             0.004176  ...
# 2                        11.335161                             0.003455  ...
# 3                        14.773936                             0.002676  ...
# 4                         7.656360                             0.004031  ...
#
#    computation_pout_MASS_FLOW  computation_pout_TORQUE  \
# 0                      20.753                   810.51
# 1                      20.393                   832.89
# 2                      20.858                   864.92
# 3                      20.217                   788.48
# 4                      20.564                   766.19
#
#    computation_pout_C_PRES_LOSS  computation_pout_STA_PRES_RATIO  \
# 0                     -5.404785                           1.0641
# 1                     -5.771030                           1.0541
# 2                     -5.582005                           1.0680
# 3                     -5.614608                           1.0495
# 4                     -5.239415                           1.0598
#
#    computation_pout_TOT_PRES_RATIO  computation_pout_P_MIN  \
# 0                           1.9177            35363.890625
# 1                           1.9371            23738.423828
# 2                           1.9601            23533.199219
# 3                           1.8919            26993.339844
# 4                           1.8690            29212.718750
#
#    computation_pout_P_MIN_SS  computation_pout_P_MIN_SS_SPLITTER  \
# 0               35363.890625                        35363.890625
# 1               23738.423828                        23738.423828
# 2               23533.199219                        23533.199219
# 3               26993.339844                        26993.339844
# 4               29212.718750                        29212.718750
#
#    computation_pout_PS_DIFF_SS  computation_pout_PS_DIFF_SS_SPLITTER
# 0                 54473.505092                          54473.505092
# 1                 65960.916451                          65960.916451
# 2                 66398.513982                          66398.513982
# 3                 62718.457183                          62718.457183
# 4                 60689.731294                          60689.731294
#
# [5 rows x 53 columns]

# %%
tabular_data.shape
# Out:
# (2000, 53)

# %%
tabular_data.describe()
# Out:
#        SEGMENT_2_RTHETA_STACKING_CURVE_POINT1  \
# count                             2000.000000
# mean                                -0.001000
# std                                  0.000578
# min                                 -0.002000
# 25%                                 -0.001499
# 50%                                 -0.000999
# 75%                                 -0.000499
# max                                  0.000000
#
#        SEGMENT_2_RTHETA_STACKING_CURVE_POINT2  \
# count                            2.000000e+03
# mean                            -9.998259e-04
# std                              5.774045e-04
# min                             -1.999812e-03
# 25%                             -1.499651e-03
# 50%                             -9.996401e-04
# 75%                             -5.003092e-04
# max                             -6.722403e-07
#
#        SEGMENT_2_RTHETA_STACKING_CURVE_POINT3  SEGMENT_2_SECTION1_CHORD  \
# count                            2.000000e+03               2000.000000
# mean                            -1.000088e-03                  0.055001
# std                              5.773700e-04                  0.002887
# min                             -1.999860e-03                  0.050005
# 25%                             -1.499532e-03                  0.052502
# 50%                             -1.000490e-03                  0.055003
# 75%                             -5.009350e-04                  0.057498
# max                             -9.878466e-07                  0.059999
#
#        SEGMENT_2_SECTION1_EXITANGLE  SEGMENT_2_SECTION1_INLETANGLE  \
# count                   2000.000000                    2000.000000
# mean                     -16.840000                     -54.599995
# std                        2.886711                       2.886789
# min                      -21.836559                     -59.596835
# 25%                      -19.338247                     -57.097974
# 50%                      -16.840192                     -54.600449
# 75%                      -14.343291                     -52.100980
# max                      -11.840139                     -49.602451
#
#        SEGMENT_2_SECTION1_LEWEDGEANGLE  SEGMENT_2_SECTION1_STAGGERANGLE  \
# count                      2000.000000                      2000.000000
# mean                          5.001536                       -38.999993
# std                           2.887517                         1.154734
# min                           0.001239                       -40.998293
# 25%                           2.503732                       -39.999488
# 50%                           5.003620                       -38.999882
# 75%                           7.503173                       -38.000977
# max                           9.997554                       -37.001743
#
#        SEGMENT_2_SECTION1_TEWEDGEANGLE  SEGMENT_2_SECTION1_THICKNESS_POINT3  \
# count                      2000.000000                          2000.000000
# mean                         12.000037                             0.003518
# std                           2.886742                             0.000577
# min                           7.003191                             0.002519
# 25%                           9.502409                             0.003018
# 50%                          12.000414                             0.003518
# 75%                          14.499184                             0.004017
# max                          16.997276                             0.004517
#
#        ...  computation_pout_MASS_FLOW  computation_pout_TORQUE  \
# count  ...                 2000.000000              2000.000000
# mean   ...                   20.422390               792.203295
# std    ...                    0.480107                47.724941
# min    ...                   18.451000               625.710000
# 25%    ...                   20.093750               758.410000
# 50%    ...                   20.458000               792.795000
# 75%    ...                   20.781250               826.762500
# max    ...                   21.489000               935.620000
#
#        computation_pout_C_PRES_LOSS  computation_pout_STA_PRES_RATIO  \
# count                   2000.000000                      2000.000000
# mean                      -5.460630                         1.056120
# std                        0.193280                         0.012578
# min                       -6.168654                         1.013000
# 25%                       -5.593078                         1.046800
# 50%                       -5.448107                         1.056450
# 75%                       -5.320932                         1.065500
# max                       -4.973868                         1.085900
#
#        computation_pout_TOT_PRES_RATIO  computation_pout_P_MIN  \
# count                      2000.000000             2000.000000
# mean                          1.890976            29539.222121
# std                           0.056034             5531.660080
# min                           1.653700            12198.536133
# 25%                           1.852700            26054.559082
# 50%                           1.892000            30091.852539
# 75%                           1.931525            33839.068360
# max                           2.045900            41107.382812
#
#        computation_pout_P_MIN_SS  computation_pout_P_MIN_SS_SPLITTER  \
# count                2000.000000                         2000.000000
# mean                29539.512564                        29539.222121
# std                  5532.194597                         5531.660080
# min                 12198.536133                        12198.536133
# 25%                 26054.559082                        26054.559082
# 50%                 30091.852539                        30091.852539
# 75%                 33839.068360                        33839.068360
# max                 41107.382812                        41107.382812
#
#        computation_pout_PS_DIFF_SS  computation_pout_PS_DIFF_SS_SPLITTER
# count                  2000.000000                           2000.000000
# mean                  60293.854816                          60294.145259
# std                    5579.927042                           5579.388000
# min                   48589.911402                          48589.911402
# 25%                   55952.962522                          55952.962522
# 50%                   59749.307853                          59749.307853
# 75%                   63839.327731                          63839.327731
# max                   77771.941356                          77771.941356
#
# [8 rows x 53 columns]

# %%
geometries =np.concatenate([np.load(geometries_path_1), np.load(geometries_path_2)], axis=0) 
geometries.shape
# Out:
# (2000, 2, 9, 112, 4)

# %%
SAMPLE_INDEX = 0

pressure_side = geometries[SAMPLE_INDEX, 1, :, :, :3].reshape(-1, 3)
suction_side = geometries[SAMPLE_INDEX, 0, :, :, :3].reshape(-1, 3)

pressure_side.shape, pressure_side.shape
# Out:
# ((1008, 3), (1008, 3))

# %%
fig = go.Figure(data=[
                      go.Scatter3d(x=pressure_side[:, 0], y=pressure_side[:, 1], z=pressure_side[:, 2],
                                   mode='markers',
                                   marker=dict(size=5),
                                   name='pressure_side'),
                      go.Scatter3d(x=suction_side[:, 0], y=suction_side[:, 1], z=suction_side[:, 2],
                                   mode='markers',
                                   marker=dict(size=5),
                                   name='suction_side'),

],
                                   layout=go.Layout(
                            width=1000,
                            height=800,
                        ))
fig.show()
